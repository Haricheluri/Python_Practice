# %% [markdown]
# Question: Check if a variable is None

# %%
variable = None
is_none = variable is None
print(f"Variable: {variable}")
print(f"Is None: {is_none}")
print("-" * 50)
# Out:
# Variable: None
# Is None: True
# --------------------------------------------------

# %% [markdown]
#  Question 1: Create a variable and assign None to it

# %%
variable1=None
print(variable1)
# Out:
# None

# %% [markdown]
# Question 2: Check if None equals None

# %%
print(f"None equals None is {None==None}")
# Out:
# None equals None is True

# %% [markdown]
#  Question 3: Check if None is None

# %%
print(f"None is None : {None is None}")
# Out:
# None is None : True

# %% [markdown]
# Question 4: Check if 0 is None

# %%
print(f"0 is None : {0 is None}")
# Out:
# 0 is None : False
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\hariharan cheluri\AppData\Local\Temp\ipykernel_23316\179087186.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print(f"0 is None : {0 is None}")

# %% [markdown]
# Question 5: Check if empty string is None

# %%
empty=""
print(f"Empty string  is None : {empty is None}")
# Out:
# Empty string  is None : False

# %% [markdown]
# Question 6: Check if False is None

# %%
print(f"False is None : {False is None}")
# Out:
# False is None : False

# %% [markdown]
# Question 7: Check if empty list is None

# %%
print(f"Empty list is None : {[] is None}")
# Out:
# Empty list is None : False

# %% [markdown]
# Question 8: Check if empty dictionary is None

# %%
print(f"Empty dictionary is None : { {} is None}")
# Out:
# Empty dictionary is None : False

# %% [markdown]
# Question 9: Check if empty tuple is None

# %%
print(f"Empty Tuple is None : {() is None}")
# Out:
# Empty Tuple is None : False
# <>:1: SyntaxWarning: "is" with 'tuple' literal. Did you mean "=="?
# C:\Users\hariharan cheluri\AppData\Local\Temp\ipykernel_23316\3135224051.py:1: SyntaxWarning: "is" with 'tuple' literal. Did you mean "=="?
#   print(f"Empty Tuple is None : {() is None}")

# %% [markdown]
# Question 10: Check if empty set is None"

# %%
print(set() is None)
# Out:
# False
