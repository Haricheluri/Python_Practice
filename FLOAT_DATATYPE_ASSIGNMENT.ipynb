# %%
import math
radius = 5.5
area = math.pi * radius ** 2
print(f"Radius: {radius}")
print(f"Area: {area:.2f}")
# Out:
# Radius: 5.5
# Area: 95.03

# %% [markdown]
# Calculate the average of 3.14, 2.718, 1.618, 0.577

# %%
sum1=3.14+2.718+1.618+0.577
avg=sum1//4
print(f"Average of the numbers {avg}")
# Out:
# Average of the numbers 2.0

# %% [markdown]
# Convert 98.6 Fahrenheit to Celsius (F = C * 9/5 + 32)

# %%
fahrenheit=98.6
celsius=(fahrenheit-32)*5/9
print(f"Temp in celsius : {celsius}")
# Out:
# Temp in celsius : 37.0

# %% [markdown]
# Question 3: Calculate the compound interest on $1000 at 5.5% for 3 years

# %%
P=1000
R=5.5
T=3
A=P*(1+R/100)**T
CI=A-P
print(f"Compound interest : {CI}")
# Out:
# Compound interest : 174.24137499999983

# %% [markdown]
# Question 4: Find the hypotenuse of a right triangle with sides 3.5 and 4.2

# %%
side1=3.5
side2=4.2
hypotenuse= (side1**2 + side2**2)**0.5
print(f"hypotenuse :{hypotenuse}")
# Out:
# hypotenuse :5.4671747731346585

# %% [markdown]
# Question 5: Calculate the volume of a sphere with radius 7.8

# %%
radius=7.8
volume_of_sphere=(4/3)*3.14*7.8**3
print(volume_of_sphere)
# Out:
# 1986.7910399999998

# %% [markdown]
# Question 6: Round 3.14159 to 3 decimal places

# %%
decimal=3.14159
print(f"Rounded number of decimal :{decimal:.3f}")
# Out:
# Rounded number of decimal :3.142

# %% [markdown]
# Question 7: Calculate the percentage: 45 out of 67

# %%
percent=(45/67)*100
print(f"Percentage : {percent}")
# Out:
# Percentage : 67.16417910447761

# %% [markdown]
# Question 8: Find the square root of 23.456

# %%
decimal_num=23.456
square_root=decimal_num**0.5
print(f"square root : {square_root}")
# Out:
# square root : 4.843139477652899

# %% [markdown]
# Question 9: Calculate the simple interest: Principal=2500, Rate=6.5%, Time=2.5 years

# %%
principle=2500
rate=6.5
time=2.5
SI=(principle*rate*time)/100
print(f"Simple interest : {SI}")
# Out:
# Simple interest : 406.25

# %% [markdown]
# Question 10: Convert 45.7 degrees to radians

# %%
degree=45.7
radians=(degree*3.14)/180
print(f"radians: {radians}")
# Out:
# radians: 0.7972111111111112
