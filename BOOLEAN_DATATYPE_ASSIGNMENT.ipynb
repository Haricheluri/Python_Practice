# %% [markdown]
# Question 1: Check if 25 is greater than 20 and less than 30

# %%
num=25
print(f"Checking 25 greater than 20 and less than 30 : {num>20 and num<30}")
# Out:
# Checking 25 greater than 20 and less than 30 : True

# %% [markdown]
# Question 2: Check if string "python" is equal to "Python" (case sensitive)

# %%
string="python"
print(f"Checking python is equal to Python: {string=="Python"}")
# Out:
# Checking python is equal to Python: False

# %% [markdown]
# Question 3: Check if 15 is divisible by both 3 and 5

# %%
digit=15
print(f"Checking 15 divisible by 3 and 5: {digit%3==0 and digit%5==0}")
# Out:
# Checking 15 divisible by 3 and 5: True

# %% [markdown]
#  Question 4: Check if 7 is not equal to 8

# %%
digit4=7
print(f"Checking 7 is not equal to 8 : {digit4==8}")
# Out:
# Checking 7 is not equal to 8 : False

# %% [markdown]
# Question 5: Check if 100 is greater than 50 or less than 25

# %%
print(f"Checking 100 is greater than 50 or less than 25: {100 > 50 or 100 < 25}")
# Out:
# Checking 100 is greater than 50 or less than 25: True

# %% [markdown]
# Question 6: Check if 0 is falsy in Python

# %%
print(f"Check 0 is falsy in Python : {0==False}")
# Out:
# Check 0 is falsy in Python : True

# %% [markdown]
#  Question 7: Check if empty string "" is falsy in Python

# %%
if not "":
    print("empty string is falsy")
# Out:
# empty string is falsy

# %% [markdown]
# Question 8: Check if 42 is truthy in Python

# %%
if 42:
    print("42 is truthy in Python")
else:
    print("42 is falsy in Python")
# Out:
# 42 is truthy in Python

# %% [markdown]
# Question 9: Check if 10 is between 5 and 15 (inclusive)

# %%
if 5 <= 10 <= 15:
    print("10 is between 5 and 15 (inclusive)")
else:
    print("10 is NOT between 5 and 15")
# Out:
# 10 is between 5 and 15 (inclusive)

# %% [markdown]
# Question 10: Check if 3.14 is greater than 3 and less than 4

# %%
if 3 < 3.14 < 4:
    print("3.14 is greater than 3 and less than 4")
else:
    print("3.14 is NOT in the range")
# Out:
# 3.14 is greater than 3 and less than 4
